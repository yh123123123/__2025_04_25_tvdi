# %% [markdown]
# 好的，我將根據您在 prompt.md 檔案中提供的技術需求，產生相應的局部 HTML 和 CSS 程式碼。
#
# 由於 banner.png 圖片未提供，我將創建一個通用的橫幅結構，其中包含一個佔位圖片和文字內容，並確保所有元素都按要求置中，且具備響應式設計 (RWD) 特性。
#
# 以下是 HTML 和 CSS 程式碼：
#
# HTML (橫幅結構):
#
# html
# <!-- AI 技術橫幅區塊 -->
# <div class="ai-banner-section">
#   <!-- 圖片容器 -->
#   <div class="ai-banner-image-wrapper">
#     <!-- 假圖，您可以替換成您的圖片路徑 -->
#     <!-- 圖片尺寸僅為範例，請依實際需求調整 -->
#     <img src="https://via.placeholder.com/800x300.png?text=AI+Banner+Image" alt="AI 技術橫幅圖片" class="ai-banner-image">
#   </div>
#   <!-- 文字內容容器 -->
#   <div class="ai-banner-text-wrapper">
#     <h2 class="ai-banner-title">AI 驅動未來科技</h2>
#     <p class="ai-banner-description">探索人工智慧的無限可能，革新您的業務與生活。</p>
#   </div>
# </div>
# CSS (橫幅樣式與響應式設計):
#
# css
# /* --- AI 橫幅基礎樣式 (行動裝置優先) --- */
# .ai-banner-section {
#   width: 100%; /* 橫幅區塊佔滿可用寬度 */
#   padding: 20px 15px; /* 上下內距 20px，左右內距 15px */
#   box-sizing: border-box; /* padding 和 border 不會增加元素總寬高，方便佈局 */
#   text-align: center; /* 內部文字內容預設置中 */
#   overflow: hidden; /* 防止內容溢出，特別是當圖片尺寸控制不當時 */
# }
#
# .ai-banner-image-wrapper {
#   margin-bottom: 15px; /* 圖片與文字之間的間距 */
# }
#
# .ai-banner-image {
#   max-width: 100%; /* 圖片最大寬度不超過其容器 */
#   height: auto; /* 高度自動調整以保持長寬比 */
#   display: block; /* 轉換為區塊元素，以使用 margin: auto 置中並消除圖片底部可能的空白間隙 */
#   margin-left: auto; /* 圖片水平置中 */
#   margin-right: auto; /* 圖片水平置中 */
# }
#
# .ai-banner-title {
#   font-size: 1.8em; /* 標題字體大小 (em 相對於父元素字體大小) */
#   color: #333333; /* 標題顏色 - 深灰色 */
#   margin-top: 0; /* 清除 h2 預設的上邊距 */
#   margin-bottom: 10px; /* 標題與描述文字的間距 */
# }
#
# .ai-banner-description {
#   font-size: 1em; /* 描述文字字體大小 */
#   color: #555555; /* 描述文字顏色 - 中灰色 */
#   line-height: 1.6; /* 行高，提升可讀性 */
#   margin-top: 0; /* 清除 p 預設的上邊距 */
#   margin-bottom: 0; /* 清除 p 預設的下邊距 (如果不需要額外空間) */
# }
#
# /* --- 中斷點：576px 以上 (通常為較大的手機橫向或小型平板直向) --- */
# @media (min-width: 576px) {
#   .ai-banner-section {
#     padding: 30px 20px; /* 調整內邊距 */
#   }
#
#   .ai-banner-title {
#     font-size: 2em; /* 略微增大標題字體 */
#   }
#
#   .ai-banner-description {
#     font-size: 1.1em; /* 略微增大描述文字字體 */
#   }
#
#   /* 範例：若圖片在此中斷點不需要佔滿100%，可以設定一個明確的最大寬度 */
#   /*
#   .ai-banner-image {
#     max-width: 500px;
#   }
#   */
# }
#
# /* --- 中斷點：768px 以上 (通常為平板橫向或小型筆記型電腦) --- */
# @media (min-width: 768px) {
#   .ai-banner-section {
#     padding: 40px 30px; /* 調整內邊距 */
#     /* 範例：若希望內容區塊在較寬螢幕上不要過寬，可以設定最大寬度並使其居中 */
#     /*
#     max-width: 720px;
#     margin-left: auto;
#     margin-right: auto;
#     */
#   }
#
#   .ai-banner-image-wrapper {
#     margin-bottom: 20px; /* 增加圖片與文字的間距 */
#   }
#
#   .ai-banner-title {
#     font-size: 2.4em; /* 增大標題字體 */
#   }
#
#   .ai-banner-description {
#     font-size: 1.2em; /* 增大描述文字字體 */
#   }
# }
#
# /* --- 中斷點：992px 以上 (通常為桌上型電腦) --- */
# @media (min-width: 992px) {
#   .ai-banner-section {
#     padding: 50px 40px; /* 調整內邊距 */
#     /* 範例：若希望內容區塊在更大螢幕上有個更舒適的最大寬度 */
#     /*
#     max-width: 960px;
#     margin-left: auto;
#     margin-right: auto;
#     */
#   }
#
#   .ai-banner-title {
#     font-size: 2.8em; /* 更大標題字體 */
#   }
#
#   .ai-banner-description {
#     font-size: 1.25em; /* 更大描述文字字體 */
#   }
# }
# 程式碼說明：
#
# HTML 結構:
#
# 使用 div 元素構建了清晰的區塊：ai-banner-section 作為整體容器，內部包含 ai-banner-image-wrapper（圖片容器）和 ai-banner-text-wrapper（文字內容容器）。
# 圖片使用 <img> 標籤，src 指向一個佔位圖片服務，您可以輕鬆替換為實際圖片路徑。alt 屬性提供了圖片的替代文字。
# 文字內容包含一個 <h2> 標題和一個 <p> 段落。
# CSS 樣式:
#
# 基礎樣式 (行動裝置優先): 首先定義了在最小螢幕尺寸下的樣式。
# .ai-banner-section 設定 width: 100% 和 text-align: center; 來使內部文字內容置中。
# .ai-banner-image 使用 display: block; 和 margin-left: auto; margin-right: auto; 來實現圖片本身的水平置中。max-width: 100%; 和 height: auto; 確保圖片響應式縮放。
# RWD 中斷點:
# 使用 @media (min-width: ...) 針對 576px、768px 和 992px 設定了不同的樣式調整。
# 在較大的螢幕尺寸下，主要調整了容器的 padding 以及標題和描述文字的 font-size，以獲得更好的視覺效果。
# CSS 註解中也提供了一些可選的範例，例如如何在特定中斷點限制圖片或內容區塊的最大寬度。
# 註解: 所有 CSS 註解均使用繁體中文，符合您的要求。
# 置中: 圖片和文字都已根據要求進行置中處理。
# 您可以將這段 HTML 和 CSS 程式碼片段整合到您的主要網頁中。希望這能滿足您的需求！
#
# Gemini Code Assist supports plain-text files. Other file types, like PDFs and images, are not directly supported at this time. If a version of the file is available in a plain text format, please use that instead, or copy the relevant contents from the file into your prompt.

# %%
html
<!-- AI 技術橫幅區塊 -->
<div class="ai-banner-section">
  <!-- 圖片容器 -->
  <div class="ai-banner-image-wrapper">
    <!-- 假圖，您可以替換成您的圖片路徑 -->
    <!-- 圖片尺寸僅為範例，請依實際需求調整 -->
    <img src="https://via.placeholder.com/800x300.png?text=AI+Banner+Image" alt="AI 技術橫幅圖片" class="ai-banner-image">
  </div>
  <!-- 文字內容容器 -->
  <div class="ai-banner-text-wrapper">
    <h2 class="ai-banner-title">AI 驅動未來科技</h2>
    <p class="ai-banner-description">探索人工智慧的無限可能，革新您的業務與生活。</p>
  </div>
</div>

# %%
css
/* --- AI 橫幅基礎樣式 (行動裝置優先) --- */
.ai-banner-section {
  width: 100%; /* 橫幅區塊佔滿可用寬度 */
  padding: 20px 15px; /* 上下內距 20px，左右內距 15px */
  box-sizing: border-box; /* padding 和 border 不會增加元素總寬高，方便佈局 */
  text-align: center; /* 內部文字內容預設置中 */
  overflow: hidden; /* 防止內容溢出，特別是當圖片尺寸控制不當時 */
}

.ai-banner-image-wrapper {
  margin-bottom: 15px; /* 圖片與文字之間的間距 */
}

.ai-banner-image {
  max-width: 100%; /* 圖片最大寬度不超過其容器 */
  height: auto; /* 高度自動調整以保持長寬比 */
  display: block; /* 轉換為區塊元素，以使用 margin: auto 置中並消除圖片底部可能的空白間隙 */
  margin-left: auto; /* 圖片水平置中 */
  margin-right: auto; /* 圖片水平置中 */
}

.ai-banner-title {
  font-size: 1.8em; /* 標題字體大小 (em 相對於父元素字體大小) */
  color: #333333; /* 標題顏色 - 深灰色 */
  margin-top: 0; /* 清除 h2 預設的上邊距 */
  margin-bottom: 10px; /* 標題與描述文字的間距 */
}

.ai-banner-description {
  font-size: 1em; /* 描述文字字體大小 */
  color: #555555; /* 描述文字顏色 - 中灰色 */
  line-height: 1.6; /* 行高，提升可讀性 */
  margin-top: 0; /* 清除 p 預設的上邊距 */
  margin-bottom: 0; /* 清除 p 預設的下邊距 (如果不需要額外空間) */
}

/* --- 中斷點：576px 以上 (通常為較大的手機橫向或小型平板直向) --- */
@media (min-width: 576px) {
  .ai-banner-section {
    padding: 30px 20px; /* 調整內邊距 */
  }

  .ai-banner-title {
    font-size: 2em; /* 略微增大標題字體 */
  }

  .ai-banner-description {
    font-size: 1.1em; /* 略微增大描述文字字體 */
  }

  /* 範例：若圖片在此中斷點不需要佔滿100%，可以設定一個明確的最大寬度 */
  /*
  .ai-banner-image {
    max-width: 500px;
  }
  */
}

/* --- 中斷點：768px 以上 (通常為平板橫向或小型筆記型電腦) --- */
@media (min-width: 768px) {
  .ai-banner-section {
    padding: 40px 30px; /* 調整內邊距 */
    /* 範例：若希望內容區塊在較寬螢幕上不要過寬，可以設定最大寬度並使其居中 */
    /*
    max-width: 720px;
    margin-left: auto;
    margin-right: auto;
    */
  }

  .ai-banner-image-wrapper {
    margin-bottom: 20px; /* 增加圖片與文字的間距 */
  }

  .ai-banner-title {
    font-size: 2.4em; /* 增大標題字體 */
  }

  .ai-banner-description {
    font-size: 1.2em; /* 增大描述文字字體 */
  }
}

/* --- 中斷點：992px 以上 (通常為桌上型電腦) --- */
@media (min-width: 992px) {
  .ai-banner-section {
    padding: 50px 40px; /* 調整內邊距 */
    /* 範例：若希望內容區塊在更大螢幕上有個更舒適的最大寬度 */
    /*
    max-width: 960px;
    margin-left: auto;
    margin-right: auto;
    */
  }

  .ai-banner-title {
    font-size: 2.8em; /* 更大標題字體 */
  }

  .ai-banner-description {
    font-size: 1.25em; /* 更大描述文字字體 */
  }
}
