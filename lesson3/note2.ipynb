# %% [markdown]
# <img src="https://r2cdn.perplexity.ai/pplx-full-logo-primary-dark%402x.png" class="logo" width="120"/>
#
# # 我要使用python open source,目的是下載網路上的檔案?有建議哪一個module嗎
#
# 如果你想用 Python 下載網路上的檔案，最推薦的 open source module 是 **requests**。這個模組簡單易用，非常適合初學者[^3][^5][^6]。
#
# **安裝方式：**
#
# ```bash
# pip install requests
# ```
#
# **簡單下載範例：**
#
# ```python
# import requests
#
# url = 'https://example.com/file.txt'
# response = requests.get(url)
#
# with open('file.txt', 'wb') as f:
#     f.write(response.content)
# ```
#
# 這樣就可以把網路上的檔案下載到本地了[^3][^5][^6]。
#
# 如果你要下載很大的檔案，可以加上串流（stream）參數，進行分段下載，減少記憶體用量。需要更進階的功能，也可以考慮 **urllib**（Python 內建模組），但初學者建議先用 requests[^5]。
#
# <div style="text-align: center">⁂</div>
#
# [^1]: https://docs.python.org/zh-tw/3.13/installing/index.html
#
# [^2]: https://docs.python.org/zh-cn/3.13/installing/index.html
#
# [^3]: https://ucomedu.blogspot.com/2020/11/python.html
#
# [^4]: https://www.youtube.com/watch?v=Et0DjY2cGiE
#
# [^5]: https://vocus.cc/article/67248204fd897800018ba4c1
#
# [^6]: https://pythonbook.cc/chapters/basic/install-python
#
# [^7]: https://www.cnblogs.com/Magiclala/p/17874710.html
#
# [^8]: https://docs.python.org/zh-tw/3/tutorial/modules.html

# %% [markdown]
# <img src="https://r2cdn.perplexity.ai/pplx-full-logo-primary-dark%402x.png" class="logo" width="120"/>
#
# ## Python 開源下載與安裝教學
#
# 你想使用 Python 開源軟體來「下載」資料或檔案，這裡提供新手友善的步驟：
#
# **1. 下載與安裝 Python**
#
# - 到 [Python 官方網站](https://python.org) 下載最新版（建議選擇 Python 3.x 版本）[^1][^3][^5]。
# - 下載後，點擊安裝檔，依照畫面指示安裝即可[^5]。
#
# **2. 安裝好 Python 後，打開命令提示字元（Windows）或終端機（Mac/Linux）**
#
# - 輸入 `python --version`，確認安裝成功會顯示版本號。
#
# **3. 安裝下載用的開源套件（以 requests 為例）**
#
# - 在命令提示字元輸入：
#
# ```
# pip install requests
# ```
#
# 這樣就能安裝 requests 這個常用的網路下載套件[^1]。
#
# **4. 使用 requests 下載檔案簡單範例**
#
# ```python
# import requests
#
# url = 'https://example.com/file.jpg'
# response = requests.get(url)
#
# with open('file.jpg', 'wb') as f:
#     f.write(response.content)
# ```
#
# 這段程式會把網路上的檔案下載到你的電腦[^1]。
#
# ---
#
# 如需其他下載功能（例如下載整個資料夾、壓縮檔等），也可以安裝其他開源套件，方法都類似。只要用 pip 安裝，再查詢該套件的用法即可[^1]。
#
# 如果還有任何 Python 下載相關問題，歡迎再問！
#
# <div style="text-align: center">⁂</div>
#
# [^1]: https://pythonbook.cc/chapters/basic/install-python
#
# [^2]: https://aws.amazon.com/tw/what-is/python/
#
# [^3]: https://ithelp.ithome.com.tw/m/articles/10350391
#
# [^4]: https://codedata.com.tw/python/python-tutorial-the-1st-class-3-hello-world-traditional-chinese-edition/
#
# [^5]: https://vocus.cc/article/66acce55fd89780001e056f8
#
# [^6]: https://pythonbook.cc/chapters/cpython/introduction
#
# [^7]: https://tw.alphacamp.co/blog/open-source-hacktoberfest
#
# [^8]: https://zh.wikipedia.org/zh-tw/Python

# %% [markdown]
# # 下載internet的資源
# -使用第3方套件(requests)
#
# https://pypi.org/project/requests/
#
# GitHub
# https://github.com/psf/requests
# 文件
# https://requests.readthedocs.io/en/latest/
#
#
# ![这是图片](./note/001.png "")
#
# -----------------------------------------------------------------------------------------
#
# 終端機指令:
# pip --version
# pip install requests
#
# ------------------------------------------------------------------------------------------
#
# 終端機畫面:
#
# (.venv) C:\Users\user\Documents\GitHub>pip --version
# pip 25.1 from c:\Users\user\Documents\GitHub\.venv\Lib\site-packages\pip (python 3.13)
#
# (.venv) C:\Users\user\Documents\GitHub>pip install requests
# Collecting requests
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.2-cp313-cp313-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Downloading urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Downloading certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.2-cp313-cp313-win_amd64.whl (105 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
# Downloading certifi-2025.4.26-py3-none-any.whl (159 kB)
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2025.4.26 charset-normalizer-3.4.2 idna-3.10 requests-2.32.3 urllib3-2.4.0
#
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# (.venv) C:\Users\user\Documents\GitHub>
#
# [def]: ./note/001.png ""

# %% [markdown]
# '''
# import requests
# from requests import Response
#
# url='https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=540e2ca4-41e1-4186-8497-fdd67024ac44&limit=1000&sort=ImportDate desc&format=CSV'
# respones:Response= requests.get(url)
# respones.text
# '''
#
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File c:\Users\user\Documents\GitHub\.venv\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File c:\Users\user\Documents\GitHub\.venv\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    File c:\Users\user\Documents\GitHub\.venv\Lib\site-packages\urllib3\connection.py:741, in HTTPSConnection.connect(self)
#     739 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 741 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     742     sock=sock,
#     743     cert_reqs=self.cert_reqs,
#     744     ssl_version=self.ssl_version,
#     745     ssl_minimum_version=self.ssl_minimum_version,
#     746     ssl_maximum_version=self.ssl_maximum_version,
#     747     ca_certs=self.ca_certs,
#     748     ca_cert_dir=self.ca_cert_dir,
#     749     ca_cert_data=self.ca_cert_data,
#     750     cert_file=self.cert_file,
#     751     key_file=self.key_file,
# ...
# --> 698         raise SSLError(e, request=request)
#     700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#
# SSLError: HTTPSConnectionPool(host='data.moenv.gov.tw', port=443): Max retries exceeded with url: /api/v2/aqx_p_432?api_key=540e2ca4-41e1-4186-8497-fdd67024ac44&limit=1000&sort=ImportDate%20desc&format=CSV (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Missing Subject Key Identifier (_ssl.c:1028)')))
# Output is truncated. View as a scrollable element or open in a text editor. Adjust cell output settings...
#
#
#
# '''
# import requests
# from requests import Response
#
# url='https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=540e2ca4-41e1-4186-8497-fdd67024ac44&limit=1000&sort=ImportDate desc&format=CSV'
# respones:Response= requests.get(url,verify=False)
# respones.text
#
# '''

# %% [markdown]
# <img src="https://r2cdn.perplexity.ai/pplx-full-logo-primary-dark%402x.png" class="logo" width="120"/>
#
# # SSLError: HTTPSConnectionPool(host='data.moenv.gov.tw', port=443): Max retries exceeded with url: /api/v2/aqx_p_432?api_key=540e2ca4-41e1-4186-8497-fdd67024ac44\&limit=1000\&sort=ImportDate%20desc\&format=CSV (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Missing Subject Key Identifier (_ssl.c:1028)')))
#
# Output is truncated. View as a scrollable element or open in a text editor. Adjust cell output settings
#
# 遇到SSL證書驗證失敗錯誤時，常見原因與解決方法如下：
#
# **1. 忽略證書驗證（僅限測試環境）**
# 使用`verify=False`參數跳過驗證，但會降低安全性：
#
# ```python
# import requests
# response = requests.get(url, verify=False)
# ```
#
# 此方法適用於臨時測試，但可能暴露中間人攻擊風險[^2][^5]。
#
# **2. 使用系統信任的證書庫**
# 安裝`pip-system-certs`套件讓Python讀取系統證書庫：
#
# ```bash
# pip install pip-system-certs
# ```
#
# 此方法自動同步Windows/Mac系統的信任證書，推薦優先嘗試[^5]。
#
# **3. 手動指定證書文件**
# 若伺服器使用自簽名證書，下載`.pem`文件後指定路徑：
#
# ```python
# response = requests.get(url, verify='/path/to/certificate.pem')
# ```
#
# 需確保證書文件包含完整信任鏈[^2][^4]。
#
# **特定錯誤處理**
# 若錯誤明確提示`Missing Subject Key Identifier`，表示伺服器證書缺少RFC5280要求的擴展字段。此時可：
#
# - 聯繫伺服器管理者更新符合規範的證書
# - 在客戶端代碼中添加`OpenSSL`配置參數（需進階系統權限）[^3][^4]
#
# 建議先嘗試方法2，若無效再考慮臨時使用方法1並儘快升級證書配置。生產環境應始終保持完整證書驗證機制。
#
# <div style="text-align: center">⁂</div>
#
# [^1]: https://stackoverflow.com/questions/77442172/ssl-certificate-verify-failed-certificate-verify-failed-unable-to-get-local-is
#
# [^2]: https://blog.csdn.net/hehengjia/article/details/133920660
#
# [^3]: https://github.com/ProxymanApp/Proxyman/issues/2226
#
# [^4]: https://github.com/pyca/cryptography/issues/11042
#
# [^5]: https://support.pyxll.com/hc/en-gb/articles/18949393753363--SSL-CERTIFICATE-VERIFY-FAILED-when-using-requests-and-https
#
# [^6]: https://discourse.pi-hole.net/t/unable-to-get-api-in-version-6-0-working-with-ssl-certificates-python/76252
#
# [^7]: https://discuss.huggingface.co/t/ssl-certifiction-error/74326
#
# [^8]: https://sslinsights.com/fix-certificate-verify-failed-error-in-python/
#
# [^9]: https://superuser.com/questions/1426277/ssl-sslcertverificationerror-ssl-certificate-verify-failed-certificate-verif
#
# [^10]: https://community.cloudera.com/t5/Support-Questions/SSLError-certificate-verify-failed/td-p/92340
#
# [^11]: https://github.com/rba-community/TA-opnsense/issues/47
#
# [^12]: https://learn.microsoft.com/en-us/troubleshoot/developer/webapps/iis/www-authentication-authorization/troubleshooting-ssl-related-issues-server-certificate

# %% [markdown]
# 政府資料開放平台
# https://data.gov.tw/
#
# 空氣品質
# https://data.gov.tw/dataset/40448
# https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=540e2ca4-41e1-4186-8497-fdd67024ac44&limit=1000&sort=ImportDate desc&format=CSV

# %% [markdown]
# <img src="https://r2cdn.perplexity.ai/pplx-full-logo-primary-dark%402x.png" class="logo" width="120"/>
#
# ## Python 的 file 物件操作教學
#
# **基本步驟**
#
# 1. 打開文件（open）
# 2. 讀寫文件內容（read/write）
# 3. 關閉文件（close）
#
# ---
#
# **1. 打開文件**
#
# 使用 `open()` 函數打開文件，會回傳一個 file 物件：
#
# ```python
# f = open('檔案路徑', '模式', encoding='utf-8')
# ```
#
# 常見模式：
#
# - `'r'`：讀取（預設）
# - `'w'`：寫入（會清空原內容）
# - `'a'`：追加
# - `'b'`：二進位模式（如 `'rb'`、`'wb'`）
#
# 範例：
#
# ```python
# f = open('test.txt', 'r', encoding='utf-8')
# ```
#
#
# ---
#
# **2. 讀寫文件內容**
#
# - 讀取：
#     - `f.read()`：讀取全部內容
#     - `f.readline()`：讀取一行
#     - `f.readlines()`：讀取所有行，回傳 list
# - 寫入：
#     - `f.write('內容')`：寫入內容
#     - `f.writelines(['多行內容'])`：寫入多行
#
# 範例：
#
# ```python
# content = f.read()
# ```
#
#
# ---
#
# **3. 關閉文件**
#
# 操作完畢後，務必關閉文件：
#
# ```python
# f.close()
# ```
#
#
# ---
#
# **4. 推薦用法：with 語句**
#
# `with` 可以自動關閉文件，更安全簡潔：
#
# ```python
# with open('test.txt', 'r', encoding='utf-8') as f:
#     content = f.read()
# ```
#
#
# ---
#
# **5. 其他常用方法**
#
# - `f.tell()`：取得目前指標位置
# - `f.seek(offset)`：移動指標到指定位置
#
# ---
#
# **小提醒**
#
# - 寫入後若要讀取，需 `f.seek(0)` 或重新 `open`，否則讀不到內容[^1]。
# - 二進位檔案請用 `'rb'`、`'wb'` 模式。
#
# ---
#
# 這些就是 Python file 物件的基本操作方法，適合初學者練習！
#
# <div style="text-align: center">⁂</div>
#
# [^1]: http://www.runoob.com/python/file-methods.html
#
# [^2]: https://docs.python.org/zh-tw/3.6/c-api/file.html
#
# [^3]: http://www.runoob.com/python/python-files-io.html
#
# [^4]: https://blog.csdn.net/yueguang8/article/details/136383215
#
# [^5]: https://www.cnblogs.com/bonheur/p/12359217.html
#
# [^6]: https://docs.python.org/zh-tw/3.13/c-api/file.html
#
# [^7]: https://blog.csdn.net/qq_41813454/article/details/137140533
#
# [^8]: https://pythonhowto.readthedocs.io/zh_CN/latest/file.html

# %% [markdown]
# '''
# import requests
# from requests import Response
#
# url='https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=540e2ca4-41e1-4186-8497-fdd67024ac44&limit=1000&sort=ImportDate desc&format=CSV'
# respones:Response= requests.get(url)
# respones.text
# '''
#
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File c:\Users\user\Documents\GitHub\.venv\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File c:\Users\user\Documents\GitHub\.venv\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    File c:\Users\user\Documents\GitHub\.venv\Lib\site-packages\urllib3\connection.py:741, in HTTPSConnection.connect(self)
#     739 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 741 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     742     sock=sock,
#     743     cert_reqs=self.cert_reqs,
#     744     ssl_version=self.ssl_version,
#     745     ssl_minimum_version=self.ssl_minimum_version,
#     746     ssl_maximum_version=self.ssl_maximum_version,
#     747     ca_certs=self.ca_certs,
#     748     ca_cert_dir=self.ca_cert_dir,
#     749     ca_cert_data=self.ca_cert_data,
#     750     cert_file=self.cert_file,
#     751     key_file=self.key_file,
# ...
# --> 698         raise SSLError(e, request=request)
#     700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#
# SSLError: HTTPSConnectionPool(host='data.moenv.gov.tw', port=443): Max retries exceeded with url: /api/v2/aqx_p_432?api_key=540e2ca4-41e1-4186-8497-fdd67024ac44&limit=1000&sort=ImportDate%20desc&format=CSV (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Missing Subject Key Identifier (_ssl.c:1028)')))
# Output is truncated. View as a scrollable element or open in a text editor. Adjust cell output settings...
#
#
#
# '''
# import requests
# from requests import Response
#
# url='https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=540e2ca4-41e1-4186-8497-fdd67024ac44&limit=1000&sort=ImportDate desc&format=CSV'
# respones:Response= requests.get(url,verify=False)
# respones.text
#
# '''

# %% [markdown]
# (.venv) C:\Users\user\Documents\GitHub>conda --version
# conda 24.11.3
#
# (.venv) C:\Users\user\Documents\GitHub>

# %% [markdown]
# Microsoft Windows [版本 10.0.26100.2605]
# (c) Microsoft Corporation. 著作權所有，並保留一切權利。
#
# (.venv) C:\Users\user\Documents\GitHub>conda env list
#
# # conda environments:
# #
# base                   D:\Users\user\anaconda3
#
#
# (.venv) C:\Users\user\Documents\GitHub>conda create --name flask python=3.11
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: D:\Users\user\anaconda3\envs\flask
#
#   added / updated specs:
#     - python=3.11
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pip-25.1                   |     pyhc872135_2         1.3 MB
#     python-3.11.11             |       h4607a30_0        18.7 MB
#     setuptools-78.1.1          |  py311haa95532_0         2.3 MB
#     tzdata-2025b               |       h04d1e81_0         116 KB
#     vc-14.42                   |       haa95532_5          11 KB
#     vs2015_runtime-14.42.34433 |       hbfb602d_5         1.2 MB
#     wheel-0.45.1               |  py311haa95532_0         182 KB
#     xz-5.6.4                   |       h4754444_1         280 KB
#     ------------------------------------------------------------
#                                            Total:        24.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   bzip2              pkgs/main/win-64::bzip2-1.0.8-h2bbff1b_6
#   ca-certificates    pkgs/main/win-64::ca-certificates-2025.2.25-haa95532_0
#   libffi             pkgs/main/win-64::libffi-3.4.4-hd77b12b_1
#   openssl            pkgs/main/win-64::openssl-3.0.16-h3f729d1_0
#   pip                pkgs/main/noarch::pip-25.1-pyhc872135_2
#   python             pkgs/main/win-64::python-3.11.11-h4607a30_0
#   setuptools         pkgs/main/win-64::setuptools-78.1.1-py311haa95532_0
#   sqlite             pkgs/main/win-64::sqlite-3.45.3-h2bbff1b_0
#   tk                 pkgs/main/win-64::tk-8.6.14-h0416ee5_0
#   tzdata             pkgs/main/noarch::tzdata-2025b-h04d1e81_0
#   vc                 pkgs/main/win-64::vc-14.42-haa95532_5
#   vs2015_runtime     pkgs/main/win-64::vs2015_runtime-14.42.34433-hbfb602d_5
#   wheel              pkgs/main/win-64::wheel-0.45.1-py311haa95532_0
#   xz                 pkgs/main/win-64::xz-5.6.4-h4754444_1
#   zlib               pkgs/main/win-64::zlib-1.2.13-h8cc25b3_1
#
#
# Proceed ([y]/n)? y
#
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate flask
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
# (.venv) C:\Users\user\Documents\GitHub>conda activate flask
#
# (flask) (.venv) C:\Users\user\Documents\GitHub>conda activate flask
#
# (flask) (.venv) C:\Users\user\Documents\GitHub>conda activate flask
#
# (flask) (.venv) C:\Users\user\Documents\GitHub>

# %% [markdown]
# import requests
# from requests import Response
#
# url='https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=540e2ca4-41e1-4186-8497-fdd67024ac44&limit=1000&sort=ImportDate desc&format=CSV'
# respones:Response= requests.get(url)
# respones.text

# %% [markdown]
# Microsoft Windows [版本 10.0.26100.2605]
# (c) Microsoft Corporation. 著作權所有，並保留一切權利。
#
# (.venv) C:\Users\user\Documents\GitHub>conda env list
#
# # conda environments:
# #
# base                   D:\Users\user\anaconda3
#
#
# (.venv) C:\Users\user\Documents\GitHub>conda create --name flask python=3.11
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: D:\Users\user\anaconda3\envs\flask
#
#   added / updated specs:
#     - python=3.11
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pip-25.1                   |     pyhc872135_2         1.3 MB
#     python-3.11.11             |       h4607a30_0        18.7 MB
#     setuptools-78.1.1          |  py311haa95532_0         2.3 MB
#     tzdata-2025b               |       h04d1e81_0         116 KB
#     vc-14.42                   |       haa95532_5          11 KB
#     vs2015_runtime-14.42.34433 |       hbfb602d_5         1.2 MB
#     wheel-0.45.1               |  py311haa95532_0         182 KB
#     xz-5.6.4                   |       h4754444_1         280 KB
#     ------------------------------------------------------------
#                                            Total:        24.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   bzip2              pkgs/main/win-64::bzip2-1.0.8-h2bbff1b_6
#   ca-certificates    pkgs/main/win-64::ca-certificates-2025.2.25-haa95532_0
#   libffi             pkgs/main/win-64::libffi-3.4.4-hd77b12b_1
#   openssl            pkgs/main/win-64::openssl-3.0.16-h3f729d1_0
#   pip                pkgs/main/noarch::pip-25.1-pyhc872135_2
#   python             pkgs/main/win-64::python-3.11.11-h4607a30_0
#   setuptools         pkgs/main/win-64::setuptools-78.1.1-py311haa95532_0
#   sqlite             pkgs/main/win-64::sqlite-3.45.3-h2bbff1b_0
#   tk                 pkgs/main/win-64::tk-8.6.14-h0416ee5_0
#   tzdata             pkgs/main/noarch::tzdata-2025b-h04d1e81_0
#   vc                 pkgs/main/win-64::vc-14.42-haa95532_5
#   vs2015_runtime     pkgs/main/win-64::vs2015_runtime-14.42.34433-hbfb602d_5
#   wheel              pkgs/main/win-64::wheel-0.45.1-py311haa95532_0
#   xz                 pkgs/main/win-64::xz-5.6.4-h4754444_1
#   zlib               pkgs/main/win-64::zlib-1.2.13-h8cc25b3_1
#
#
# Proceed ([y]/n)? y
#
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate flask
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
# (.venv) C:\Users\user\Documents\GitHub>conda activate flask
#
# (flask) (.venv) C:\Users\user\Documents\GitHub>conda activate flask
#
# (flask) (.venv) C:\Users\user\Documents\GitHub>conda activate flask
#
# (flask) (.venv) C:\Users\user\Documents\GitHub>pip install requests
# Collecting requests
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.2-cp311-cp311-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Using cached urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Using cached certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.2-cp311-cp311-win_amd64.whl (105 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached urllib3-2.4.0-py3-none-any.whl (128 kB)
# Using cached certifi-2025.4.26-py3-none-any.whl (159 kB)
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2025.4.26 charset-normalizer-3.4.2 idna-3.10 requests-2.32.3 urllib3-2.4.0
#
# (flask) (.venv) C:\Users\user\Documents\GitHub>

# %% [markdown]
# Microsoft Windows [版本 10.0.26100.2605]
# (c) Microsoft Corporation. 著作權所有，並保留一切權利。
#
# (.venv) C:\Users\user\Documents\GitHub>conda deactivate
#
# (.venv) C:\Users\user\Documents\GitHub>conda activate flask
#
# (flask) (.venv) C:\Users\user\Documents\GitHub>pip install requests
# Requirement already satisfied: requests in d:\users\user\anaconda3\envs\flask\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\users\user\anaconda3\envs\flask\lib\site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\user\anaconda3\envs\flask\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\users\user\anaconda3\envs\flask\lib\site-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\user\anaconda3\envs\flask\lib\site-packages (from requests) (2025.4.26)
#
# (flask) (.venv) C:\Users\user\Documents\GitHub>
