# %% [markdown]
# 附上footer.pnp
#
# # 建立HTML的footer區塊和產生CSS
# 1. 請單獨建立<footer>的元素
# 2. 這個footer未來會整合到我的網頁內
# 3. layout請參考footer.pnp
# 4. 左邊的圖片,請先使用假圖,未來我會替換它

# %% [markdown]
# It sounds like you're working on building the footer for your website! I can definitely help you create the HTML structure and the CSS to match the layout you've described in footer.pnp. Let's get this done.
#
# HTML
#
# <footer>
#   <div class="footer-container">
#     <div class="footer-left">
#       <img src="placeholder-logo.png" alt="Logo">
#       <p>JustHome</p>
#     </div>
#     <div class="footer-middle">
#       <div class="footer-column">
#         <h3>Discover</h3>
#         <ul>
#           <li><a href="#">Link 1</a></li>
#           <li><a href="#">Link 2</a></li>
#           <li><a href="#">Link 3</a></li>
#         </ul>
#       </div>
#       <div class="footer-column">
#         <h3>Quick Links</h3>
#         <ul>
#           <li><a href="#">Link A</a></li>
#           <li><a href="#">Link B</a></li>
#           <li><a href="#">Link C</a></li>
#         </ul>
#       </div>
#       <div class="footer-column">
#         <h3>Contact Us</h3>
#         <ul>
#           <li><a href="#">Email</a></li>
#           <li><a href="#">Phone</a></li>
#           <li><a href="#">Form</a></li>
#         </ul>
#       </div>
#       <div class="footer-column address">
#         <h3>Our Address</h3>
#         <p>123 Main Street,<br>
#            Shilin District, Taipei City,<br>
#            Taiwan</p>
#       </div>
#     </div>
#     <div class="footer-right">
#       <h3>Get the app</h3>
#       <a href="#"><img src="placeholder-app-store.png" alt="App Store"></a>
#       <a href="#"><img src="placeholder-google-play.png" alt="Google Play"></a>
#     </div>
#   </div>
# </footer>
# CSS
#
# footer {
#   background-color: #f0f8ff; /* A light blue background, adjust as needed */
#   padding: 20px;
#   color: #333; /* Dark text for readability */
# }
#
# .footer-container {
#   display: flex;
#   justify-content: space-between;
#   align-items: flex-start;
#   max-width: 1200px; /* Adjust for your website's width */
#   margin: 0 auto;
# }
#
# .footer-left {
#   display: flex;
#   align-items: center;
# }
#
# .footer-left img {
#   width: 50px; /* Adjust the size of your logo */
#   height: auto;
#   margin-right: 10px;
# }
#
# .footer-middle {
#   display: flex;
#   gap: 40px; /* Spacing between the columns */
# }
#
# .footer-column h3 {
#   margin-top: 0;
#   margin-bottom: 10px;
# }
#
# .footer-column ul {
#   list-style: none;
#   padding: 0;
#   margin: 0;
# }
#
# .footer-column li {
#   margin-bottom: 5px;
# }
#
# .footer-column a {
#   text-decoration: none;
#   color: #555;
# }
#
# .footer-column a:hover {
#   color: #007bff; /* Example hover color */
# }
#
# .footer-column.address p {
#   line-height: 1.5;
# }
#
# .footer-right {
#   text-align: center;
# }
#
# .footer-right h3 {
#   margin-top: 0;
#   margin-bottom: 10px;
# }
#
# .footer-right img {
#   width: 120px; /* Adjust the size of your app store badges */
#   height: auto;
#   margin: 5px 0;
# }
#
# /* Responsive adjustments (optional) */
# @media (max-width: 768px) {
#   .footer-container {
#     flex-direction: column;
#     align-items: center;
#     text-align: center;
#   }
#
#   .footer-middle {
#     flex-direction: column;
#     gap: 20px;
#     margin-top: 20px;
#   }
#
#   .footer-column {
#     text-align: center;
#   }
#
#   .footer-left {
#     margin-bottom: 20px;
#   }
#
#   .footer-right {
#     margin-top: 20px;
#   }
# }
# Explanation:
#
# HTML Structure (<footer>):
#
# We start with the <footer> element as requested.
# Inside, we have a div with the class footer-container to help organize the content and center it.
# We've divided the footer into three main sections: footer-left, footer-middle, and footer-right to align with a typical footer layout.
# footer-left: Contains a placeholder image (placeholder-logo.png) and the "JustHome" text. Remember to replace placeholder-logo.png with your actual logo image.
# footer-middle: This section uses a flexbox layout to arrange columns for "Discover," "Quick Links," "Contact Us," and "Our Address." Each column has a heading (h3) and a list (ul) of links (li and a). The "Our Address" column has a paragraph (p) for the address details.
# footer-right: Contains the "Get the app" heading and placeholder images for app store badges (placeholder-app-store.png and placeholder-google-play.png). Replace these with your actual app store badge images.
# CSS Styling:
#
# footer: Sets a light blue background color (#f0f8ff), adds some padding around the content, and sets the default text color to dark gray (#333). You can easily change the background-color to match your website's theme.
# .footer-container: Uses display: flex to arrange the main sections horizontally with justify-content: space-between to put space between them. align-items: flex-start aligns the items to the top. max-width and margin: 0 auto help center the footer content on larger screens.
# .footer-left: Uses display: flex and align-items: center to place the logo and text side-by-side and vertically aligned.
# .footer-left img: Styles the placeholder logo image, setting its width and adding some right margin.
# .footer-middle: Uses display: flex and gap to create spacing between the columns.
# .footer-column: Styles the headings (h3) and unordered lists (ul) within each column.
# .footer-column a: Styles the links, removing the default underline and setting a color. A :hover effect is added for visual feedback.
# .footer-column.address p: Adds some line height to the address text for better readability.
# .footer-right: Centers the content within the right section.
# .footer-right img: Styles the placeholder app store badge images.
# @media (max-width: 768px) (Responsive Adjustments): This is an optional section that makes the footer more responsive on smaller screens (like tablets and mobile devices). It changes the footer-container to a column layout, centers the text, and adjusts the spacing of the elements.
# To integrate this into your website:
#
# Save the HTML code as part of your website's HTML structure, usually at the end of your <body> tag.
# Save the CSS code in your main CSS file or within <style> tags in your HTML's <head> section.
# Replace the placeholder image paths (placeholder-logo.png, placeholder-app-store.png, placeholder-google-play.png) with the actual paths to your image files.
# Update the links (<a href="#">) and the text content within the footer with your actual information.
# Let me know if you have any other questions or need further adjustments! I'm here to help.

# %%
<footer>
  <div class="footer-container">
    <div class="footer-left">
      <img src="placeholder-logo.png" alt="Logo">
      <p>JustHome</p>
    </div>
    <div class="footer-middle">
      <div class="footer-column">
        <h3>Discover</h3>
        <ul>
          <li><a href="#">Link 1</a></li>
          <li><a href="#">Link 2</a></li>
          <li><a href="#">Link 3</a></li>
        </ul>
      </div>
      <div class="footer-column">
        <h3>Quick Links</h3>
        <ul>
          <li><a href="#">Link A</a></li>
          <li><a href="#">Link B</a></li>
          <li><a href="#">Link C</a></li>
        </ul>
      </div>
      <div class="footer-column">
        <h3>Contact Us</h3>
        <ul>
          <li><a href="#">Email</a></li>
          <li><a href="#">Phone</a></li>
          <li><a href="#">Form</a></li>
        </ul>
      </div>
      <div class="footer-column address">
        <h3>Our Address</h3>
        <p>123 Main Street,<br>
           Shilin District, Taipei City,<br>
           Taiwan</p>
      </div>
    </div>
    <div class="footer-right">
      <h3>Get the app</h3>
      <a href="#"><img src="placeholder-app-store.png" alt="App Store"></a>
      <a href="#"><img src="placeholder-google-play.png" alt="Google Play"></a>
    </div>
  </div>
</footer>

# %%
footer {
  background-color: #f0f8ff; /* A light blue background, adjust as needed */
  padding: 20px;
  color: #333; /* Dark text for readability */
}

.footer-container {
  display: flex;
  justify-content: space-between;
  align-items: flex-start;
  max-width: 1200px; /* Adjust for your website's width */
  margin: 0 auto;
}

.footer-left {
  display: flex;
  align-items: center;
}

.footer-left img {
  width: 50px; /* Adjust the size of your logo */
  height: auto;
  margin-right: 10px;
}

.footer-middle {
  display: flex;
  gap: 40px; /* Spacing between the columns */
}

.footer-column h3 {
  margin-top: 0;
  margin-bottom: 10px;
}

.footer-column ul {
  list-style: none;
  padding: 0;
  margin: 0;
}

.footer-column li {
  margin-bottom: 5px;
}

.footer-column a {
  text-decoration: none;
  color: #555;
}

.footer-column a:hover {
  color: #007bff; /* Example hover color */
}

.footer-column.address p {
  line-height: 1.5;
}

.footer-right {
  text-align: center;
}

.footer-right h3 {
  margin-top: 0;
  margin-bottom: 10px;
}

.footer-right img {
  width: 120px; /* Adjust the size of your app store badges */
  height: auto;
  margin: 5px 0;
}

/* Responsive adjustments (optional) */
@media (max-width: 768px) {
  .footer-container {
    flex-direction: column;
    align-items: center;
    text-align: center;
  }

  .footer-middle {
    flex-direction: column;
    gap: 20px;
    margin-top: 20px;
  }

  .footer-column {
    text-align: center;
  }

  .footer-left {
    margin-bottom: 20px;
  }

  .footer-right {
    margin-top: 20px;
  }
}
